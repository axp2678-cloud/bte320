# %% [markdown]
# <a href="https://colab.research.google.com/github/axp2678-cloud/bte320/blob/main/In_Class_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Sales = float(input("Enter sales amount ($)"))
cost_of_goods_sold = Sales * 0.4
gross_profit = Sales - cost_of_goods_sold
print(f"Total Costs of Goods Sold: {cost_of_goods_sold}$")
print(f"Gross Profit: {gross_profit}$")
# Out:
# Enter sales amount ($)12000
# Total Costs of Goods Sold: 4800.0$
# Gross Profit: 7200.0$
